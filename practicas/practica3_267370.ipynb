# %% [markdown]
# <a href="https://colab.research.google.com/github/marioarsw/AnaliticaDescriptiva/blob/main/practicas/practica3_267370.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Maestría en Inteligencia Artificial y Analítica de Datos
#
#
# *   Curso: Programación para Analítica Descriptiva y Predictiva
# *   Semestre: Enero-Junio
# *   Profesor: Dr. Vicente García Jiménez

# %% [markdown]
# ## Práctica 3: Arrelgos con NumPy
#
# ## Mario Amador - 267370.
#
# Creación de un arreglo y operaciones básicas.
#
# Crea un arreglo unidimensional de 20 elementos con valores aleatorios entre 1 y 100. Luego, realiza las siguientes operaciones:
#
# 1.   Encuentra el valor máximo del arreglo.
# 2.   Encuentra el valor mínimo del arreglo.
# 3.   Calcula la media del arreglo.
# 4.   Suma 10 a cada elemento del arreglo.

# %% [markdown]
# Imporación de librerías.

# %%
import numpy as np

# %% [markdown]
# Crea un arreglo unidimensional de 20 elementos con valores aleatorios entre 1 y 100

# %%
array = np.random.randint(1, 101, 20)
array
# Out:
# array([25, 23, 82, 91, 45, 60, 93, 41, 29, 52, 22, 94, 98, 56, 49, 19, 35,
#        34,  4, 31])

# %% [markdown]
# 1. Encuentra el valor máximo del arreglo.

# %%
np.max(array)
# Out:
# np.int64(98)

# %% [markdown]
# 2. Encuentra el valor mínimo del arreglo.

# %%
np.min(array)
# Out:
# np.int64(4)

# %% [markdown]
# 3. Calcula la media del arreglo.

# %%
np.mean(array)
# Out:
# np.float64(49.15)

# %% [markdown]
# 4. Suma 10 a cada elemento del arreglo.

# %%
array+10
# Out:
# array([ 35,  33,  92, 101,  55,  70, 103,  51,  39,  62,  32, 104, 108,
#         66,  59,  29,  45,  44,  14,  41])
